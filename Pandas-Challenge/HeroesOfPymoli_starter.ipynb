# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data
len(purchase_data['SN'].unique())
# Out:
# 576

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = len(purchase_data ['Item Name'].unique())
average_price = purchase_data ['Price'].mean()
total_revenue = purchase_data ['Price'].sum()
purchase_numbers = len(purchase_data)
summary_df = pd.DataFrame({'Unique Items': [unique_items], 'Average Price': [average_price], 'Total Revenue': [total_revenue], 'Purchase Numbers': [purchase_numbers]})
summary_df
# Out:
#    Unique Items  Average Price  Total Revenue  Purchase Numbers
# 0           179       3.050987        2379.77               780

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
unique_df = purchase_data.drop_duplicates(subset = 'SN')
male_female = unique_df['Gender'].value_counts()
male_female/576
# Out:
# Male                     0.840278
# Female                   0.140625
# Other / Non-Disclosed    0.019097
# Name: Gender, dtype: float64

# %%
purchase_numbers
# Out:
# 780

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
grouped_df = purchase_data.groupby('Gender')
average_price = grouped_df ['Price'].mean()
total_revenue = grouped_df ['Price'].sum()
purchase_numbers = grouped_df['Price'].count()
summary_df = pd.DataFrame({ 'Average Price': average_price, 'Total Revenue': total_revenue, 'Purchase Numbers': purchase_numbers})
summary_df
# Out:
#                        Average Price  Total Revenue  Purchase Numbers
# Gender
# Female                      3.203009         361.94               113
# Male                        3.017853        1967.64               652
# Other / Non-Disclosed       3.346000          50.19                15

# %% [markdown]
# ## Age Demographics

# %%
age_bins = [0,20,30,40,1000] 
age_names = ['0-20', '21-30','31-40','40+']
purchase_data["Age Bin Column"] = pd.cut(purchase_data['Age'], age_bins, labels = age_names)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Bin Column
# 0    Extraction, Quickblade Of Trembling Hands   3.53           0-20
# 1                            Frenzied Scimitar   1.56          31-40
# 2                                 Final Critic   4.88          21-30
# ...

# %%
bin_group = purchase_data.groupby('Age Bin Column')
bin_count = bin_group['SN'].count()
percentages = bin_count/len(purchase_data)
bin_count
percentages
distribution = pd.DataFrame({'Count': bin_count, 'Percentage': percentages})
distribution
# Out:
#                 Count  Percentage
# Age Bin Column
# 0-20              286    0.366667
# 21-30             402    0.515385
# 31-40              85    0.108974
# 40+                 7    0.008974

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
mean = bin_group['Price'].mean()
SUM = bin_group ['Price'].sum()
per_person = SUM / bin_count
analysis = pd.DataFrame ({'Count': bin_count, 'Mean': mean , 'Summed Total': SUM, 'Purchase Total Per Person': per_person})
analysis
# Out:
#                 Count      Mean  Summed Total  Purchase Total Per Person
# Age Bin Column
# 0-20              286  3.101818        887.12                   3.101818
# 21-30             402  2.992687       1203.06                   2.992687
# 31-40              85  3.153647        268.06                   3.153647
# 40+                 7  3.075714         21.53                   3.075714

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
grouped_SN = purchase_data.groupby('SN')
purchase_count = grouped_SN['Price'].count()
average_purchase_price = grouped_SN['Price'].mean()
total_purchase_value = grouped_SN ['Price'].sum()
Spenders = pd.DataFrame({'Purchase Count': purchase_count, 'Average Purchase Price': average_purchase_price, 'Total Purchase Value': total_purchase_value})
Spenders
spenders_sorted = Spenders.sort_values('Total Purchase Value', ascending = False)
spenders_sorted
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10
# ...                     ...                     ...                   ...
# Ililsasya43               1                1.020000                  1.02
# Irilis75                  1                1.020000                  1.02
# Aidai61                   1                1.010000                  1.01
# Chanirra79                1                1.010000                  1.01
# Alo38                     1                1.000000                  1.00
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
grouped_itemname = purchase_data.groupby(['Item Name', 'Item ID'])
purchase_count = grouped_itemname['Price'].count()
item_price = grouped_itemname ['Price'].mean()
total_purchase_value = grouped_itemname ['Price'].sum()
ID = pd.DataFrame({'Purchase Count': purchase_count, 'Item Price': item_price, 'Total Purchase': total_purchase_value})
ID
itemname_sorted = ID.sort_values('Total Purchase', ascending = False)
itemname_sorted
ID
# Out:
#                                          Purchase Count  Item Price  \
# Item Name                       Item ID
# Abyssal Shard                   162                   5        2.67
# Aetherius, Boon of the Blessed  137                   5        3.39
# Agatha                          120                   6        3.08
# Alpha                           130                   3        2.07
# Alpha, Oath of Zeal             79                    3        4.05
# ...                                                 ...         ...
# Wolf                            60                    8        3.54
# Wolf, Promise of the Moonwalker 179                   6        4.48
# Worldbreaker                    112                   4        2.60
# Yearning Crusher                74                    3        4.18
# Yearning Mageblade              114                   5        3.82
#
#                                          Total Purchase
# Item Name                       Item ID
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
itemname_sorted
# Out:
#                                                       Purchase Count  \
# Item Name                                    Item ID
# Final Critic                                 92                   13
# Oathbreaker, Last Hope of the Breaking Storm 178                  12
# Nirvana                                      82                    9
# Fiery Glass Crusader                         145                   9
# Singed Scalpel                               103                   8
# ...                                                              ...
# Flux, Destroyer of Due Diligence             28                    2
# Whistling Mithril Warblade                   125                   2
# Exiled Mithril Longsword                     126                   1
# Gladiator's Glaive                           104                   1
# The Decapitator                              42                    1
#
#                                                       Item Price  \
# ...
